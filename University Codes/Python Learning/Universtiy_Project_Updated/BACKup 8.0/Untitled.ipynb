# %%
import pandas as pd
data = pd.read_csv('nba-players-stats/ShootingOverTheYears1.csv' ,index_col='Rank')

display(data)
# Out:
#       Season     G     MP    FG   FGA  ThreeP  ThreePA    PTS  FGPercent  \
# Rank
# 1       2018  1230  241.6  41.1  89.2    11.4     32.0  111.2      0.461
# 2       2017  1230  241.4  39.6  86.1    10.5     29.0  106.3      0.460
# 3       2016  1230  241.6  39.0  85.4     9.7     27.0  105.6      0.457
# 4       2015  1230  241.8  38.2  84.6     8.5     24.1  102.7      0.452
# 5       2014  1230  242.0  37.5  83.6     7.8     22.4  100.0      0.449
# 6       2013  1230  242.0  37.7  83.0     7.7     21.5  101.0      0.454
# 7       2012  1229  241.9  37.1  82.0     7.2     20.0   98.1      0.453
# 8       2011   990  241.9  36.5  81.4     6.4     18.4   96.3      0.448
# 9       2010  1230  241.9  37.2  81.2     6.5     18.0   99.6      0.459
# 10      2009  1230  241.7  37.7  81.7     6.4     18.1  100.4      0.461
# 11      2008  1230  241.7  37.1  80.9     6.6     18.1  100.0      0.459
# 12      2007  1230  241.5  37.3  81.5     6.6     18.1   99.9      0.457
# 13      2006  1230  242.2  36.5  79.7     6.1     16.9   98.7      0.458
# 14      2005  1230  242.1  35.8  79.0     5.7     16.0   97.0      0.454
# 15      2004  1230  241.9  35.9  80.3     5.6     15.8   97.2      0.447
# 16      2003  1189  241.7  35.0  79.8     5.2     14.9   93.4      0.439
# 17      2002  1189  242.0  35.7  80.8     5.1     14.7   95.1      0.442
# 18      2001  1189  241.7  36.2  81.3     5.2     14.7   95.5      0.445
# 19      2000  1189  242.0  35.7  80.6     4.8     13.7   94.8      0.443
# 20      1999  1189  241.5  36.8  82.1     4.8     13.7   97.5      0.449
# 21      1998   725  241.8  34.2  78.2     4.5     13.2   91.6      0.437
# 22      1997  1189  241.9  35.9  79.7     4.4     12.7   95.6      0.450
# 23      1996  1189  241.9  36.1  79.3     6.0     16.8   96.9      0.455
# 24      1995  1189  241.6  37.0  80.2     5.9     16.0   99.5      0.462
# 25      1994  1107  241.9  38.0  81.5     5.5     15.3  101.4      0.466
# 26      1993  1107  241.1  39.3  84.4     3.3      9.9  101.5      0.466
# 27      1992  1107  241.7  40.7  86.0     3.0      9.0  105.3      0.473
# 28      1991  1107  241.8  41.3  87.3     2.5      7.6  105.3      0.472
# 29      1990  1107  241.8  41.4  87.2     2.3      7.1  106.3      0.474
# 30      1989  1107  241.5  41.5  87.2     2.2      6.6  107.0      0.476
# 31      1988  1025  241.5  42.5  89.0     2.1      6.6  109.2      0.477
# 32      1987   943  241.3  42.1  87.7     1.6      5.0  108.2      0.480
# 33      1986   943  241.6  42.6  88.8     1.4      4.7  109.9      0.480
# 34      1985   943  241.6  43.2  88.6     0.9      3.3  110.2      0.487
# 35      1984   943  241.4  43.8  89.1     0.9      3.1  110.8      0.491
# 36      1983   943  242.0  43.5  88.4     0.6      2.4  110.1      0.492
# 37      1982   943  241.3  43.5  89.7     0.5      2.3  108.5      0.485
# 38      1981   943  241.6  43.3  88.2     0.6      2.3  108.6      0.491
# 39      1980   943  241.4  43.0  88.4     0.5      2.0  108.1      0.486
# 40      1979   902  241.8  43.6  90.6     0.8      2.8  109.3      0.481
#
#       ThreePPercent   Pace   ORtg  TotalThree  TotalAttemptThree      Times  \
# Rank
# 1             0.355  100.0  110.4       27955              78742  2010-2018
# 2             0.362   97.3  108.6       25807              71337  2010-2018
# 3             0.358   96.4  108.8       23748              66422  2010-2018
# 4             0.354   95.8  106.4       20953              59241  2010-2018
# 5             0.350   93.9  105.6       19300              55137  2010-2018
# 6             0.360   93.9  106.6       19054              52974  2010-2018
# 7             0.359   92.0  105.8       17603              49067  2010-2018
# 8             0.349   91.3  104.6       12693              36395  2010-2018
# 9             0.358   92.1  107.3       15886              44313  2010-2018
# 10            0.355   92.7  107.6       15822              44622  2001-2009
# 11            0.367   91.7  108.3       16352              44583  2001-2009
# 12            0.362   92.4  107.5       16124              42092  2001-2009
# 13            0.358   91.9  106.5       14926              41672  2001-2009
# 14            0.358   90.5  106.2       14086              39313  2001-2009
# 15            0.356   90.9  106.1       13777              38748  2001-2009
# 16            0.347   90.1  102.9       12321              35492  2001-2009
# 17            0.349   91.0  103.6       12200              34912  2001-2009
# 18            0.354   90.7  104.5       12402              35074  2001-2009
# 19            0.354   91.3  103.0       11524              32597  2001-2009
# 20            0.353   93.1  104.1       11513              32614  1991-2000
# 21            0.339   88.9  102.2        6463              19080  1991-2000
# 22            0.346   90.3  105.0       10450              30231  1991-2000
# 23            0.360   90.1  106.7       14383              39943  1991-2000
# 24            0.367   91.8  107.6       14000              38161  1991-2000
# 25            0.359   92.9  108.3       12153              33889  1991-2000
# 26            0.333   95.1  106.3        7301              21907  1991-2000
# 27            0.336   96.8  108.0        6668              19824  1991-2000
# 28            0.331   96.6  108.2        5587              16898  1991-2000
# 29            0.320   97.8  107.9        5055              15812  1991-2000
# 30            0.331   98.3  108.1        4829              14608  1979-1990
# 31            0.323  100.6  107.8        4332              13431  1979-1990
# 32            0.316   99.6  108.0        2979               9421  1979-1990
# 33            0.301  100.8  108.3        2687               8913  1979-1990
# 34            0.282  102.1  107.2        1774               6293  1979-1990
# 35            0.282  102.1  107.9        1671               5917  1979-1990
# 36            0.250  101.4  107.6        1120               4484  1979-1990
# 37            0.238  103.1  104.7        1011               4248  1979-1990
# 38            0.262  100.9  106.9        1129               4308  1979-1990
# 39            0.245  101.8  105.5         936               3815  1979-1990
# 40            0.280  103.1  105.3        1403               5003  1979-1990
#
#       ThreeMAvgPerGame  ThreePAverage Seasonplus
# Rank
# 1                    0              0    2018-19
# 2                  860           2378    2017-18
# 3                  792           2214    2016-17
# 4                  698           1975    2015-16
# 5                  643           1838    2014-15
# 6                  635           1766    2013-14
# 7                  587           1636    2012-13
# 8                  423           1213    2011-12
# 9                  530           1477    2010-11
# 10                 527           1487    2009-10
# 11                 545           1486    2008-09
# 12                 537           1485    2007-08
# 13                 498           1389    2006-07
# 14                 470           1310    2005-06
# 15                 459           1292    2004-05
# 16                 425           1224    2003-04
# 17                 421           1204    2002-03
# 18                 428           1209    2001-02
# 19                 397           1124    2000-01
# 20                 397           1125    1999-00
# 21                 223            658    1998-99
# 22                 360           1042    1997-98
# 23                 496           1377    1996-97
# 24                 483           1316    1995-96
# 25                 450           1255    1994-95
# 26                 270            811    1993-94
# 27                 247            734    1992-93
# 28                 207            626    1991-92
# 29                 187            586    1990-91
# 30                 179            541    1989-90
# 31                 173            537    1988-89
# 32                 130            410    1987-88
# 33                 117            388    1986-87
# 34                  77            274    1985-86
# 35                  73            257    1984-85
# 36                  49            195    1983-84
# 37                  44            185    1982-83
# 38                  49            187    1981-82
# 39                  41            166    1980-81
# 40                  64            227    1979-80

# %%
data3 = pd.read_csv('archive/Seasons_Stats.csv',index_col=['Year'])
# Out:
#         Unnamed: 0             Player  Pos   Age   Tm     G    GS      MP  \
# Year
# 1950.0           0    Curly Armstrong  G-F  31.0  FTW  63.0   NaN     NaN
# 1950.0           1       Cliff Barker   SG  29.0  INO  49.0   NaN     NaN
# 1950.0           2      Leo Barnhorst   SF  25.0  CHS  67.0   NaN     NaN
# 1950.0           3         Ed Bartels    F  24.0  TOT  15.0   NaN     NaN
# 1950.0           4         Ed Bartels    F  24.0  DNN  13.0   NaN     NaN
# ...            ...                ...  ...   ...  ...   ...   ...     ...
# 2017.0       24686        Cody Zeller   PF  24.0  CHO  62.0  58.0  1725.0
# 2017.0       24687       Tyler Zeller    C  27.0  BOS  51.0   5.0   525.0
# 2017.0       24688  Stephen Zimmerman    C  20.0  ORL  19.0   0.0   108.0
# 2017.0       24689        Paul Zipser   SF  22.0  CHI  44.0  18.0   843.0
# 2017.0       24690        Ivica Zubac    C  19.0  LAL  38.0  11.0   609.0
#
#          PER    TS%  ...    FT%    ORB    DRB    TRB    AST   STL   BLK   TOV  \
# Year                 ...
# 1950.0   NaN  0.368  ...  0.705    NaN    NaN    NaN  176.0   NaN   NaN   NaN
# 1950.0   NaN  0.435  ...  0.708    NaN    NaN    NaN  109.0   NaN   NaN   NaN
# 1950.0   NaN  0.394  ...  0.698    NaN    NaN    NaN  140.0   NaN   NaN   NaN
# 1950.0   NaN  0.312  ...  0.559    NaN    NaN    NaN   20.0   NaN   NaN   NaN
# 1950.0   NaN  0.308  ...  0.548    NaN    NaN    NaN   20.0   NaN   NaN   NaN
# ...      ...    ...  ...    ...    ...    ...    ...    ...   ...   ...   ...
# 2017.0  16.7  0.604  ...  0.679  135.0  270.0  405.0   99.0  62.0  58.0  65.0
# 2017.0  13.0  0.508  ...  0.564   43.0   81.0  124.0   42.0   7.0  21.0  20.0
# 2017.0   7.3  0.346  ...  0.600   11.0   24.0   35.0    4.0   2.0   5.0   3.0
# 2017.0   6.9  0.503  ...  0.775   15.0  110.0  125.0   36.0  15.0  16.0  40.0
# 2017.0  17.0  0.547  ...  0.653   41.0  118.0  159.0   30.0  14.0  33.0  30.0
#
#            PF    PTS
# Year
# 1950.0  217.0  458.0
# 1950.0   99.0  279.0
# 1950.0  192.0  438.0
# 1950.0   29.0   63.0
# 1950.0   27.0   59.0
# ...       ...    ...
# 2017.0  189.0  639.0
# 2017.0   61.0  178.0
# 2017.0   17.0   23.0
# 2017.0   78.0  240.0
# 2017.0   66.0  284.0
#
# [24691 rows x 52 columns]

# %%
import pandas as pd
data = pd.read_csv('archive/Seasons_Stats.csv' )
filterminutesmorethan1500 = data.query('MP > 1500')
display(filterminutesmorethan1500)
# Out:
#        Unnamed: 0    Year           Player Pos   Age   Tm     G    GS      MP  \
# 488           488  1952.0     Paul Arizin*  SF  23.0  PHW  66.0   NaN  2939.0
# 490           490  1952.0   Don Barksdale*  PF  28.0  BLB  62.0   NaN  2014.0
# 491           491  1952.0    Leo Barnhorst  SF  27.0  INO  66.0   NaN  2344.0
# 496           496  1952.0        Don Boven  SG  26.0  MLH  66.0   NaN  1982.0
# 498           498  1952.0    Frankie Brian  SG  28.0  FTW  66.0   NaN  2672.0
# ...           ...     ...              ...  ..   ...  ...   ...   ...     ...
# 24667       24667  2017.0     Lou Williams  SG  30.0  TOT  81.0   1.0  1994.0
# 24670       24670  2017.0  Marvin Williams  PF  30.0  CHO  76.0  76.0  2295.0
# 24684       24684  2017.0       Nick Young  SG  31.0  LAL  60.0  60.0  1556.0
# 24685       24685  2017.0   Thaddeus Young  PF  28.0  IND  74.0  74.0  2237.0
# 24686       24686  2017.0      Cody Zeller  PF  24.0  CHO  62.0  58.0  1725.0
#
#         PER  ...    FT%    ORB    DRB    TRB    AST    STL   BLK    TOV  \
# 488    25.5  ...  0.818    NaN    NaN  745.0  170.0    NaN   NaN    NaN
# 490    15.8  ...  0.691    NaN    NaN  601.0  137.0    NaN   NaN    NaN
# 491    15.9  ...  0.652    NaN    NaN  430.0  255.0    NaN   NaN    NaN
# 496    12.4  ...  0.731    NaN    NaN  336.0  177.0    NaN   NaN    NaN
# 498    14.8  ...  0.848    NaN    NaN  232.0  233.0    NaN   NaN    NaN
# ...     ...  ...    ...    ...    ...    ...    ...    ...   ...    ...
# 24667  21.4  ...  0.880   26.0  176.0  202.0  239.0   80.0  19.0  160.0
# 24670  13.7  ...  0.873   89.0  409.0  498.0  106.0   58.0  53.0   60.0
# 24684  14.1  ...  0.856   25.0  112.0  137.0   58.0   37.0  14.0   36.0
# 24685  14.9  ...  0.523  131.0  318.0  449.0  122.0  114.0  30.0   96.0
# 24686  16.7  ...  0.679  135.0  270.0  405.0   99.0   62.0  58.0   65.0
#
#           PF     PTS
# 488    250.0  1674.0
# 490    230.0   781.0
# 491    196.0   820.0
# 496    271.0   656.0
# 498    220.0  1051.0
# ...      ...     ...
# 24667   92.0  1421.0
# 24670  134.0   849.0
# 24684  137.0   791.0
# 24685  135.0   814.0
# 24686  189.0   639.0
#
# [9035 rows x 53 columns]

# %%
import pandas as pd
#Get all files info
df = pd.read_csv('archive/Seasons_Stats.csv' )
#Get names that contain more than Curry
mask = df[df['Player'].str.contains('Curry',na=False)]
#Get all names that has only 1500 minutes and name is equal to Dell Curry
filterminutesmorethan1500 = mask.loc[(mask['MP']>1500) & (mask['Player']=="Stephen Curry")]
#display(mask)
filter
attempt ='3PA'
#winners.bidtime.mean()
display(filterminutesmorethan1500['3P'])
# remove the nan or na values or display nan values 
#ValueError: Cannot mask with non-boolean array containing NA / NaN values
#filterminutesmorethan1500 =data.loc[data['Player']]
# Filter rows where Age is greater than 30 using .query()
# Out:
# 20042    166.0
# 20654    151.0
# 21798    272.0
# 22402    261.0
# 23000    286.0
# 23633    402.0
# 24216    324.0
# Name: 3P, dtype: float64

# %%
import pandas as pd
from bokeh.io import output_notebook 
output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1263">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.io import output_notebook
import pandas as pd
from bokeh.models import ColumnDataSource
from bokeh.models import HoverTool
from bokeh.models import LinearInterpolator
from bokeh.models import CategoricalColorMapper
from bokeh.models import Circle
from bokeh.io import show 
from bokeh.plotting import figure

data = pd.read_csv('nba-players-stats/ShootingOverTheYears1.csv' ,index_col='Rank')

source = ColumnDataSource(dict(
    threeP = data.ThreeP,  
    threePA = data.ThreePA,
    Season=data.Season,
    G = data.G,
    TotalThree = data.TotalThree,
    TotalAttemptThree = data.TotalAttemptThree,
    Times = data.Times,
    P = data.ThreePPercent,
    seasont = data.Seasonplus
))

mapping_coloring = CategoricalColorMapper(
    factors = list(data.Times.unique()),
    palette = ['#e41a1c',
 '#377eb8',
 '#4daf4a',
 '#984ea3',
 '#ff7f00',]
)

relative_size = LinearInterpolator(
    x = [data.TotalThree.min(),data.TotalThree.max()],
    y = [10,70]
)

Hover_tool = HoverTool(tooltips = [
     ('Season', '@seasont'),
    ('3P Mades per Game', "@threeP"),
     ('3P Attempted Per Game', "@threePA"),
      ('Total Three Made', "@TotalThree"),
   ('Percentage', '@P')
])
Hover_tool1 = HoverTool(tooltips = [
     ('Season', '@seasont'),
   # ('3P Mades per Game', "@threeP"),
     ('3P Attempted Per Game', "@threePA"),
      ('Total Three Made', "@TotalThree"),
   ('Percentage', '@P')
])
Hover_tool2 = HoverTool(tooltips = [
     ('Season', '@seasont'),
 ('3P Mades per Game', "@threeP"),
    # ('3P Attempted Per Game', "@ThreePA"),
      ('Total Three Made', "@TotalThree"),
   ('Percentage', '@P')
])

p1 = figure( tools = [Hover_tool,'box_select','zoom_in','pan', 'wheel_zoom','box_zoom','reset','crosshair','lasso_select','tap'],
            height = 500,
           width = 500,
           x_range = (0,40),
           y_range=(0,15),
           title = "Three Points Stats per Season",
          x_axis_label = "3P attempts per Game Average",
           y_axis_label = "3P made per Game Average",
          toolbar_location="right")

g = p1.circle(x ='threePA',
         y ='threeP',
         size = {'field':'TotalThree','transform':relative_size},
          color = {'field': 'Times','transform': mapping_coloring},
         alpha = 0.4,
         legend_field = 'Times',
         source = source)
p1.cross(x ='threePA',
         y ='threeP',
         size = {'field':'TotalThree','transform':relative_size},
          color = {'field': 'Times','transform': mapping_coloring},
         alpha = 0.4,
        legend_field  = 'Times',
         source = source)


selected_circle = Circle(fill_alpha=0.8, fill_color="firebrick", line_color=None)
nonselected_circle = Circle(fill_alpha=0.2, fill_color={'field': 'Times','transform': mapping_coloring},line_color=None)
g.selection_glyph = selected_circle
g.nonselection_glyph = nonselected_circle


p2 = figure( tools = [Hover_tool1,'pan', 'wheel_zoom','box_zoom','reset','crosshair','lasso_select','tap','box_select'],
            height = 500,
           width = 500,
           y_range = (0,40),
           x_range=(1978,2020),
           title = "Three Points Attempts Per Season",
          x_axis_label = "Year",
           y_axis_label = "Attempt",
          toolbar_location="right")

g = p2.circle(y ='threePA',
         x ='Season',
         size = {'field':'TotalThree','transform':relative_size},
          color = {'field': 'Times','transform': mapping_coloring},
         alpha = 0.4,
         legend_label = 'Times',
         source = source)
p2.cross(y ='threePA',
         x ='Season',
         size = {'field':'TotalThree','transform':relative_size},
          color = {'field': 'Times','transform': mapping_coloring},
         alpha = 0.4,
          legend_label  = 'Times',
         source = source)
p2.line( y= 'threePA',
         x ='Season',
         alpha = 0.4,
        line_width = 3,
         source = source)

selected_circle = Circle(fill_alpha=0.8, fill_color="firebrick", line_color=None)
nonselected_circle = Circle(fill_alpha=0.2, fill_color={'field': 'Times','transform': mapping_coloring},line_color=None)

g.selection_glyph = selected_circle
g.nonselection_glyph = nonselected_circle

p3 = figure( tools = [Hover_tool2,'pan', 'wheel_zoom','box_zoom','reset','crosshair','lasso_select','tap','box_select'],
            height =500,
           width = 500,
           y_range = (0,20),
           x_range=(1978,2020),
           title = "Three Point Make Per Season",
          x_axis_label = "Year",
           y_axis_label = "Made",
          toolbar_location="right")

g = p3.circle(y ='threeP',
         x ='Season',
         size = {'field':'TotalThree','transform':relative_size},
          color = {'field': 'Times','transform': mapping_coloring},
         alpha = 0.4,
          legend_label  = 'Times',
         source = source)
p3.cross(y ='threeP',
         x ='Season',
         size = {'field':'TotalThree','transform':relative_size},
          color = {'field': 'Times','transform': mapping_coloring},
         alpha = 0.4,
          legend_label  = 'Times',
         source = source)
p3.line( y = 'threeP',
         x ='Season',
         alpha = 0.4,
        line_width = 3,
         source = source)



selected_circle = Circle(fill_alpha=0.8, fill_color="firebrick", line_color=None)
nonselected_circle = Circle(fill_alpha=0.2, fill_color={'field': 'Times','transform': mapping_coloring},line_color=None)

g.selection_glyph = selected_circle
g.nonselection_glyph = nonselected_circle


# p1.legend.click_policy="hide"

p2.legend.click_policy="hide"
p3.legend.click_policy="hide"
p1.right= p1.legend 
p2.right = p2.legend 
p3.right = p3.legend 


from bokeh.layouts import gridplot,row,column
# row1 = [p1,p2]
# row2 = [p3]
# layout = gridplot([[p1,p2],[p3]])



layout = row(column(p1,p2), p3)
show(layout)
# Out:
#   <div class="bk-root" id="db7c0e9c-d5fc-4383-89e5-a699e7026e1c" data-root-id="2239"></div>

# %%
from bokeh.io import output_notebook
import pandas as pd
from bokeh.models import ColumnDataSource
from bokeh.models import HoverTool
from bokeh.models import LinearInterpolator
from bokeh.models import CategoricalColorMapper
from bokeh.models import Circle
from bokeh.io import show 
from bokeh.plotting import figure

data = pd.read_csv('nba-players-stats/ShootingOverTheYears1.csv' ,index_col='Rank')

source = ColumnDataSource(dict(
    threeP = data.ThreeP,  
    threePA = data.ThreePA,
    Season=data.Season,
    G = data.G,
    TotalThree = data.TotalThree,
    TotalAttemptThree = data.TotalAttemptThree,
    Times = data.Times,
    P = data.ThreePPercent,
    seasont = data.Seasonplus
))

mapping_coloring = CategoricalColorMapper(
    factors = list(data.Times.unique()),
    palette = ['#e41a1c',
 '#377eb8',
 '#4daf4a',
 '#984ea3',
 '#ff7f00',]
)

relative_size = LinearInterpolator(
    x = [data.TotalThree.min(),data.TotalThree.max()],
    y = [10,70]
)

Hover_tool = HoverTool(tooltips = [
     ('Season', '@seasont'),
    ('3P Mades per Game', "@threeP"),
     ('3P Attempted Per Game', "@threePA"),
      ('Total Three Made', "@TotalThree"),
   ('Percentage', '@P')
])
Hover_tool1 = HoverTool(tooltips = [
     ('Season', '@seasont'),
   # ('3P Mades per Game', "@threeP"),
     ('3P Attempted Per Game', "@threePA"),
      ('Total Three Made', "@TotalThree"),
   ('Percentage', '@P')
])
Hover_tool2 = HoverTool(tooltips = [
     ('Season', '@seasont'),
 ('3P Mades per Game', "@threeP"),
    # ('3P Attempted Per Game', "@ThreePA"),
      ('Total Three Made', "@TotalThree"),
   ('Percentage', '@P')
])

p1 = figure( tools = [Hover_tool,'box_select','zoom_in','pan', 'wheel_zoom','box_zoom','reset','crosshair','lasso_select','tap'],
            height = 500,
           width = 500,
           x_range = (0,40),
           y_range=(0,15),
           title = "Three Points Stats per Season",
          x_axis_label = "3P attempts per Game Average",
           y_axis_label = "3P made per Game Average",
          toolbar_location="right")

g = p1.circle(x ='threePA',
         y ='threeP',
         size = {'field':'TotalThree','transform':relative_size},
          color = {'field': 'Times','transform': mapping_coloring},
         alpha = 0.4,
         legend_field = 'Times',
         source = source)
p1.cross(x ='threePA',
         y ='threeP',
         size = {'field':'TotalThree','transform':relative_size},
          color = {'field': 'Times','transform': mapping_coloring},
         alpha = 0.4,
        legend_field  = 'Times',
         source = source)


selected_circle = Circle(fill_alpha=0.8, fill_color="firebrick", line_color=None)
nonselected_circle = Circle(fill_alpha=0.2, fill_color={'field': 'Times','transform': mapping_coloring},line_color=None)
g.selection_glyph = selected_circle
g.nonselection_glyph = nonselected_circle


p2 = figure( tools = [Hover_tool1,'pan', 'wheel_zoom','box_zoom','reset','crosshair','lasso_select','tap','box_select'],
            height = 500,
           width = 500,
           y_range = (0,40),
           x_range=(1978,2020),
           title = "Three Points Attempts Per Season",
          x_axis_label = "Year",
           y_axis_label = "Attempt",
          toolbar_location="right")

g = p2.circle(y ='threePA',
         x ='Season',
         size = {'field':'TotalThree','transform':relative_size},
          color = {'field': 'Times','transform': mapping_coloring},
         alpha = 0.4,
         legend_label = 'Times',
         source = source)
p2.cross(y ='threePA',
         x ='Season',
         size = {'field':'TotalThree','transform':relative_size},
          color = {'field': 'Times','transform': mapping_coloring},
         alpha = 0.4,
          legend_label  = 'Times',
         source = source)
p2.line( y= 'threePA',
         x ='Season',
         alpha = 0.4,
        line_width = 3,
         source = source)

selected_circle = Circle(fill_alpha=0.8, fill_color="firebrick", line_color=None)
nonselected_circle = Circle(fill_alpha=0.2, fill_color={'field': 'Times','transform': mapping_coloring},line_color=None)

g.selection_glyph = selected_circle
g.nonselection_glyph = nonselected_circle

p3 = figure( tools = [Hover_tool2,'pan', 'wheel_zoom','box_zoom','reset','crosshair','lasso_select','tap','box_select'],
            height =500,
           width = 500,
           y_range = (0,20),
           x_range=(1978,2020),
           title = "Three Point Make Per Season",
          x_axis_label = "Year",
           y_axis_label = "Made",
          toolbar_location="right")

g = p3.circle(y ='threeP',
         x ='Season',
         size = {'field':'TotalThree','transform':relative_size},
          color = {'field': 'Times','transform': mapping_coloring},
         alpha = 0.4,
          legend_label  = 'Times',
         source = source)
p3.cross(y ='threeP',
         x ='Season',
         size = {'field':'TotalThree','transform':relative_size},
          color = {'field': 'Times','transform': mapping_coloring},
         alpha = 0.4,
          legend_label  = 'Times',
         source = source)
p3.line( y = 'threeP',
         x ='Season',
         alpha = 0.4,
        line_width = 3,
         source = source)



selected_circle = Circle(fill_alpha=0.8, fill_color="firebrick", line_color=None)
nonselected_circle = Circle(fill_alpha=0.2, fill_color={'field': 'Times','transform': mapping_coloring},line_color=None)

g.selection_glyph = selected_circle
g.nonselection_glyph = nonselected_circle


# p1.legend.click_policy="hide"

p2.legend.click_policy="hide"
p3.legend.click_policy="hide"
p1.right= p1.legend 
p2.right = p2.legend 
p3.right = p3.legend 


from bokeh.layouts import gridplot,row,column
# row1 = [p1,p2]
# row2 = [p3]
# layout = gridplot([[p1,p2],[p3]])



layout = row(column(p1,p2), p3)
show(layout)
# Out:
#   <div class="bk-root" id="bfc34a8d-6fb4-4654-83b4-d854b59f8a2b" data-root-id="2725"></div>

# %%
import pandas as pd
from bokeh.models import ColumnDataSource
from bokeh.models import HoverTool
from bokeh.models import LinearInterpolator
from bokeh.models import CategoricalColorMapper
from bokeh.palettes import Magma8, Inferno, Plasma, Viridis, Cividis
from ipywidgets import interact, interactive, fixed, interact_manual,widgets
from bokeh.io import push_notebook,show
import numpy as np
from bokeh.models import CategoricalColorMapper
from bokeh.palettes import Spectral6

# Creating the CategoricalColorMapper
mapping_coloring = CategoricalColorMapper(factors=unique_values, palette=palette)
data3 = pd.read_csv('archive/Seasons_Stats.csv',index_col=['Year'])
data3.loc[data3["Pos"] == "G-F", "Pos"] = 'G'
data3.loc[data3["Pos"] == "F-C", "Pos"] = 'F'
data3.loc[data3["Pos"] == "F-G", "Pos"] = 'F'
data3.loc[data3["Pos"] == "C-F", "Pos"] = 'C'
data3.loc[data3["Pos"] == "PF-C", "Pos"] = 'PF'
data3.loc[data3["Pos"] == "SF-SG", "Pos"] = 'SF'
data3.loc[data3["Pos"] == "SG-SF", "Pos"] = 'SG'
data3.loc[data3["Pos"] == "SF-PF", "Pos"] = 'SF'
data3.loc[data3["Pos"] == "SF-PG", "Pos"] = 'SF'
data3.loc[data3["Pos"] == "C-SF", "Pos"] = 'C'
data3.loc[data3["Pos"] == "PG-SG", "Pos"] = 'PG'
data3.loc[data3["Pos"] == "PG-SF", "Pos"] = 'PG'
data3.loc[data3["Pos"] == "SG-PF", "Pos"] = 'SG'
data3.loc[data3["Pos"] == "PF-SF", "Pos"] = 'PF'
data3.loc[data3["Pos"] == "SG-PG", "Pos"] = 'SG'
data3.loc[data3["Pos"] == "C-PF", "Pos"] = 'C'
data3.loc[data3["Pos"] == None, "Pos"] = '?'

display(data3)

source = ColumnDataSource(dict(
     y = data3.loc[2010,'3P'],  
    x  = data3.loc[2010,'3PA'],
    Percentages = data3.loc[2010,'3P%'],
    Player = data3.loc[2010].Player,
   Position = data3.loc[2010].Pos
))

#['G-F', 'SG', 'SF', 'F', 'G', 'F-C', 'PG', 'F-G', 'C', 'PF', 'C-F', nan, 'PF-C', 'SF-SG', 'C-PF', 'SG-SF', 'PF-SF', 'SF-PF', 'SG-PG', 'SF-PG', 'C-SF', 'PG-SG', 'PG-SF', 'SG-PF']
#'C-PF', 'PF-SF', 'SG-PG'
display(len(Magma))
display(data3.Pos)
display(data3.Pos.unique())
display(data3.Pos.unique())
display(list(data3.Pos.unique()))
# Out:
#         Unnamed: 0             Player Pos   Age   Tm     G    GS      MP  \
# Year
# 1950.0           0    Curly Armstrong   G  31.0  FTW  63.0   NaN     NaN
# 1950.0           1       Cliff Barker  SG  29.0  INO  49.0   NaN     NaN
# 1950.0           2      Leo Barnhorst  SF  25.0  CHS  67.0   NaN     NaN
# 1950.0           3         Ed Bartels   F  24.0  TOT  15.0   NaN     NaN
# 1950.0           4         Ed Bartels   F  24.0  DNN  13.0   NaN     NaN
# ...            ...                ...  ..   ...  ...   ...   ...     ...
# 2017.0       24686        Cody Zeller  PF  24.0  CHO  62.0  58.0  1725.0
# 2017.0       24687       Tyler Zeller   C  27.0  BOS  51.0   5.0   525.0
# 2017.0       24688  Stephen Zimmerman   C  20.0  ORL  19.0   0.0   108.0
# 2017.0       24689        Paul Zipser  SF  22.0  CHI  44.0  18.0   843.0
# 2017.0       24690        Ivica Zubac   C  19.0  LAL  38.0  11.0   609.0
#
#          PER    TS%  ...    FT%    ORB    DRB    TRB    AST   STL   BLK   TOV  \
# Year                 ...
# 1950.0   NaN  0.368  ...  0.705    NaN    NaN    NaN  176.0   NaN   NaN   NaN
# 1950.0   NaN  0.435  ...  0.708    NaN    NaN    NaN  109.0   NaN   NaN   NaN
# 1950.0   NaN  0.394  ...  0.698    NaN    NaN    NaN  140.0   NaN   NaN   NaN
# 1950.0   NaN  0.312  ...  0.559    NaN    NaN    NaN   20.0   NaN   NaN   NaN
# 1950.0   NaN  0.308  ...  0.548    NaN    NaN    NaN   20.0   NaN   NaN   NaN
# ...      ...    ...  ...    ...    ...    ...    ...    ...   ...   ...   ...
# 2017.0  16.7  0.604  ...  0.679  135.0  270.0  405.0   99.0  62.0  58.0  65.0
# 2017.0  13.0  0.508  ...  0.564   43.0   81.0  124.0   42.0   7.0  21.0  20.0
# 2017.0   7.3  0.346  ...  0.600   11.0   24.0   35.0    4.0   2.0   5.0   3.0
# 2017.0   6.9  0.503  ...  0.775   15.0  110.0  125.0   36.0  15.0  16.0  40.0
# 2017.0  17.0  0.547  ...  0.653   41.0  118.0  159.0   30.0  14.0  33.0  30.0
#
#            PF    PTS
# Year
# 1950.0  217.0  458.0
# 1950.0   99.0  279.0
# 1950.0  192.0  438.0
# 1950.0   29.0   63.0
# 1950.0   27.0   59.0
# ...       ...    ...
# 2017.0  189.0  639.0
# 2017.0   61.0  178.0
# 2017.0   17.0   23.0
# 2017.0   78.0  240.0
# 2017.0   66.0  284.0
#
# [24691 rows x 52 columns]
# 10
# Year
# 1950.0     G
# 1950.0    SG
# 1950.0    SF
# 1950.0     F
# 1950.0     F
#           ..
# 2017.0    PF
# 2017.0     C
# 2017.0     C
# 2017.0    SF
# 2017.0     C
# Name: Pos, Length: 24691, dtype: object
# array(['G', 'SG', 'SF', 'F', 'PG', 'C', 'PF', nan], dtype=object)
# array(['G', 'SG', 'SF', 'F', 'PG', 'C', 'PF', nan], dtype=object)
# ['G', 'SG', 'SF', 'F', 'PG', 'C', 'PF', nan]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[172], line 52
#      49 display(data3.Pos.unique())
#      50 display(list(data3.Pos.unique()))
# ---> 52 mapping_coloring = CategoricalColorMapper(
#      53     factors = list(data3['Pos'].unique()),
#      54     palette = Magma8[:len(data3['Pos'].unique())]
#      55 )
#
# File ~\anaconda3\lib\site-packages\bokeh\models\mappers.py:98, in ColorMapper.__init__(self, palette, **kwargs)
#      96 if palette is not None:
#      97     kwargs['palette'] = palette
# ---> 98 super().__init__(**kwargs)
#
# File ~\anaconda3\lib\site-packages\bokeh\model\model.py:128, in Model.__init__(self, **kwargs)
#     121 def __init__(self, **kwargs: Any) -> None:
#     122
#     123     # "id" is popped from **kw in __new__, so in an ideal world I don't
#     124     # think it should be here too. But Python has subtle behavior here, so
#     125     # it is necessary
#     126     kwargs.pop("id", None)
# --> 128     super().__init__(**kwargs)
#     129     default_theme.apply_to_model(self)
#
# File ~\anaconda3\lib\site-packages\bokeh\core\has_props.py:206, in HasProps.__init__(self, **properties)
#     203 self._unstable_themed_values = {}
#     205 for name, value in properties.items():
# --> 206     setattr(self, name, value)
#     208 self._initialized = True
#
# File ~\anaconda3\lib\site-packages\bokeh\core\has_props.py:230, in HasProps.__setattr__(self, name, value)
#     228 properties = self.properties(_with_props=True)
#     229 if name in properties:
# --> 230     return super().__setattr__(name, value)
#     232 descriptor = getattr(self.__class__, name, None)
#     233 if isinstance(descriptor, property): # Python property
#
# File ~\anaconda3\lib\site-packages\bokeh\core\property\descriptors.py:283, in PropertyDescriptor.__set__(self, obj, value, setter)
#     280     class_name = obj.__class__.__name__
#     281     raise RuntimeError(f"{class_name}.{self.name} is a readonly property")
# --> 283 value = self.property.prepare_value(obj, self.name, value)
#     284 old = self._get(obj)
#     285 self._set(obj, old, value, setter=setter)
#
# File ~\anaconda3\lib\site-packages\bokeh\core\property\bases.py:365, in Property.prepare_value(self, owner, name, value, hint)
#     363 else:
#     364     obj_repr = owner if isinstance(owner, HasProps) else owner.__name__
# --> 365     raise ValueError(f"failed to validate {obj_repr}.{name}: {error}")
#     367 if isinstance(owner, HasProps):
#     368     obj = owner
#
# ValueError: failed to validate CategoricalColorMapper(id='3697', ...).factors: expected an element of either Seq(String), Seq(Tuple(String, String)) or Seq(Tuple(String, String, String)), got ['G', 'SG', 'SF', 'F', 'PG', 'C', 'PF', nan]

# %%
import pandas as pd
from bokeh.models import ColumnDataSource
from bokeh.models import HoverTool
from bokeh.models import LinearInterpolator
from bokeh.models import CategoricalColorMapper
from bokeh.palettes import Magma8, Inferno, Plasma, Viridis, Cividis,Spectral,Set1_9
from ipywidgets import interact, interactive, fixed, interact_manual,widgets
from bokeh.io import push_notebook,show
import numpy as np
from bokeh.models import CategoricalColorMapper
from bokeh.core.validation import silence
from bokeh.core.validation.warnings import EMPTY_LAYOUT
silence(EMPTY_LAYOUT, True)

# Creating the CategoricalColorMapper
data3 = pd.read_csv('archive/Seasons_Stats.csv',index_col=['Year'])
data3.loc[data3["Pos"] == "G-F", "Pos"] = 'G'
data3.loc[data3["Pos"] == "F-C", "Pos"] = 'F'
data3.loc[data3["Pos"] == "F-G", "Pos"] = 'F'
data3.loc[data3["Pos"] == "C-F", "Pos"] = 'C'
data3.loc[data3["Pos"] == "PF-C", "Pos"] = 'PF'
data3.loc[data3["Pos"] == "SF-SG", "Pos"] = 'SF'
data3.loc[data3["Pos"] == "SG-SF", "Pos"] = 'SG'
data3.loc[data3["Pos"] == "SF-PF", "Pos"] = 'SF'
data3.loc[data3["Pos"] == "SF-PG", "Pos"] = 'SF'
data3.loc[data3["Pos"] == "C-SF", "Pos"] = 'C'
data3.loc[data3["Pos"] == "PG-SG", "Pos"] = 'PG'
data3.loc[data3["Pos"] == "PG-SF", "Pos"] = 'PG'
data3.loc[data3["Pos"] == "SG-PF", "Pos"] = 'SG'
data3.loc[data3["Pos"] == "PF-SF", "Pos"] = 'PF'
data3.loc[data3["Pos"] == "SG-PG", "Pos"] = 'SG'
data3.loc[data3["Pos"] == "C-PF", "Pos"] = 'C'
data3.loc[data3["Pos"] == None, "Pos"] = '?'

display(data3)

source = ColumnDataSource(dict(
     y = data3.loc[2010,'3P'],  
    x  = data3.loc[2010,'3PA'],
    Percentages = data3.loc[2010,'3P%'],
    Player = data3.loc[2010].Player,
   Position = data3.loc[2010].Pos
))


#data3 = pd.read_csv('archive/Seasons_Stats.csv',index_col=['Year'])

#['G-F', 'SG', 'SF', 'F', 'G', 'F-C', 'PG', 'F-G', 'C', 'PF', 'C-F', nan, 'PF-C', 'SF-SG', 'C-PF', 'SG-SF', 'PF-SF', 'SF-PF', 'SG-PG', 'SF-PG', 'C-SF', 'PG-SG', 'PG-SF', 'SG-PF']
#'C-PF', 'PF-SF', 'SG-PG'
#display(len(Magma))
#display(data3.Pos)
#display(data3.Pos.unique())
#display(data3.Pos.unique())
#display(list(data3.Pos.unique()))
#['G-F', 'SG', 'SF', 'F', 'G', 'F-C', 'PG', 'F-G', 'C', 'PF', 'C-F', nan, 'PF-C', 'SF-SG', 'C-PF', 'SG-SF', 'PF-SF', 'SF-PF', 'SG-PG', 'SF-PG', 'C-SF', 'PG-SG', 'PG-SF', 'SG-PF']
#'C-PF', 'PF-SF', 'SG-PG'
mapping_coloring = CategoricalColorMapper(
    factors = list(data3.Pos.unique()),
    palette = Set1_9
)

Hover_tools = HoverTool(tooltips = [
    ('3P Mades per Game', "@y"),
     ('3P Attempted Per Game', "@x"),
    ('3P Percentage','@Percentages'),
 ('Position', '@Position'),('Player','@Player')])

p = figure(height=600,
           width = 700,
           x_range = (0,1000),
           y_range=(0,450),
           tools = [Hover_tools,'pan', 'wheel_zoom','box_zoom','reset'],
         title = "Players Three Mades and Attempts Comparisons through the years.",
          x_axis_label = "Three Attempted",
          y_axis_label = "Three Made")

p.circle('x',
         'y', 
         size = 10,
         #size = {'field':'population','transform':relative_size},
       #  title = "Players Three Mades and Attempts Comparisons through the years.",
         color = {'field': 'Position','transform': mapping_coloring},
         alpha = 0.4,
         legend = 'Position',
        source = source)

p.cross('x',
         'y', 
         size = 25,
         #size = {'field':'population','transform':relative_size},
        color = {'field': 'Position','transform': mapping_coloring},
         alpha = 0.4,
         legend = 'Position',
        source = source)


def update(Year):
    interactivedata = dict(     
        y = data3.loc[Year,'3P'],  
    x  = data3.loc[Year,'3PA'],
    Percentages = data3.loc[Year,'3P%'],
    Player = data3.loc[Year].Player,
   Position = data3.loc[Year].Pos,
   # Team = data3.loc[Year].Tm,
    #MP = data3.loc[Year].MP
    )
    
    source.data = interactivedata
    p.title.text="Players Three Mades and Attempts Comparisons through the years. " + " Current Years:"+ str(Year)
   # p.title.text_font_size = fontsize 10;
    push_notebook()


p.legend.orientation = "vertical"
p.legend.border_line_color = "blue"
p.legend.background_fill_color = "white"
p.right = p.legend
show(p,notebook_handle=True)

interact(update,
    Year = widgets.IntSlider(
    value=0,
    min=1980,
    max=2017,
    step=1,
    description='Slider Year:',
    continuous_update=True,
    orientation='Horizontal',
    readout=True,
    readout_format='d',
));

interact(update,
    Year = widgets.Play( 
    value=0,
    min=1979,
    max=2017,
    step=1,
    disabled=False
));
    

interact(update,
    Year = widgets.BoundedIntText(
    value=0,
    min=1980,
    max=2017,
   # continuous_update=True,
    step=1,
    description='Put A Year:',
    disabled=False
));
# Out:
#         Unnamed: 0             Player Pos   Age   Tm     G    GS      MP  \
# Year
# 1950.0           0    Curly Armstrong   G  31.0  FTW  63.0   NaN     NaN
# 1950.0           1       Cliff Barker  SG  29.0  INO  49.0   NaN     NaN
# 1950.0           2      Leo Barnhorst  SF  25.0  CHS  67.0   NaN     NaN
# 1950.0           3         Ed Bartels   F  24.0  TOT  15.0   NaN     NaN
# 1950.0           4         Ed Bartels   F  24.0  DNN  13.0   NaN     NaN
# ...            ...                ...  ..   ...  ...   ...   ...     ...
# 2017.0       24686        Cody Zeller  PF  24.0  CHO  62.0  58.0  1725.0
# 2017.0       24687       Tyler Zeller   C  27.0  BOS  51.0   5.0   525.0
# 2017.0       24688  Stephen Zimmerman   C  20.0  ORL  19.0   0.0   108.0
# 2017.0       24689        Paul Zipser  SF  22.0  CHI  44.0  18.0   843.0
# 2017.0       24690        Ivica Zubac   C  19.0  LAL  38.0  11.0   609.0
#
#          PER    TS%  ...    FT%    ORB    DRB    TRB    AST   STL   BLK   TOV  \
# Year                 ...
# 1950.0   NaN  0.368  ...  0.705    NaN    NaN    NaN  176.0   NaN   NaN   NaN
# 1950.0   NaN  0.435  ...  0.708    NaN    NaN    NaN  109.0   NaN   NaN   NaN
# 1950.0   NaN  0.394  ...  0.698    NaN    NaN    NaN  140.0   NaN   NaN   NaN
# 1950.0   NaN  0.312  ...  0.559    NaN    NaN    NaN   20.0   NaN   NaN   NaN
# 1950.0   NaN  0.308  ...  0.548    NaN    NaN    NaN   20.0   NaN   NaN   NaN
# ...      ...    ...  ...    ...    ...    ...    ...    ...   ...   ...   ...
# 2017.0  16.7  0.604  ...  0.679  135.0  270.0  405.0   99.0  62.0  58.0  65.0
# 2017.0  13.0  0.508  ...  0.564   43.0   81.0  124.0   42.0   7.0  21.0  20.0
# 2017.0   7.3  0.346  ...  0.600   11.0   24.0   35.0    4.0   2.0   5.0   3.0
# 2017.0   6.9  0.503  ...  0.775   15.0  110.0  125.0   36.0  15.0  16.0  40.0
# 2017.0  17.0  0.547  ...  0.653   41.0  118.0  159.0   30.0  14.0  33.0  30.0
#
#            PF    PTS
# Year
# 1950.0  217.0  458.0
# 1950.0   99.0  279.0
# 1950.0  192.0  438.0
# 1950.0   29.0   63.0
# 1950.0   27.0   59.0
# ...       ...    ...
# 2017.0  189.0  639.0
# 2017.0   61.0  178.0
# 2017.0   17.0   23.0
# 2017.0   78.0  240.0
# 2017.0   66.0  284.0
#
# [24691 rows x 52 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[197], line 57
#      37 source = ColumnDataSource(dict(
#      38      y = data3.loc[2010,'3P'],
#      39     x  = data3.loc[2010,'3PA'],
#    (...)
#      42    Position = data3.loc[2010].Pos
#      43 ))
#      46 #data3 = pd.read_csv('archive/Seasons_Stats.csv',index_col=['Year'])
#      47
#      48 #['G-F', 'SG', 'SF', 'F', 'G', 'F-C', 'PG', 'F-G', 'C', 'PF', 'C-F', nan, 'PF-C', 'SF-SG', 'C-PF', 'SG-SF', 'PF-SF', 'SF-PF', 'SG-PG', 'SF-PG', 'C-SF', 'PG-SG', 'PG-SF', 'SG-PF']
#    (...)
#      55 #['G-F', 'SG', 'SF', 'F', 'G', 'F-C', 'PG', 'F-G', 'C', 'PF', 'C-F', nan, 'PF-C', 'SF-SG', 'C-PF', 'SG-SF', 'PF-SF', 'SF-PF', 'SG-PG', 'SF-PG', 'C-SF', 'PG-SG', 'PG-SF', 'SG-PF']
#      56 #'C-PF', 'PF-SF', 'SG-PG'
# ---> 57 mapping_coloring = CategoricalColorMapper(
#      58     factors = list(data3.Pos.unique()),
#      59     palette = Set1_9
#      60 )
#      62 Hover_tools = HoverTool(tooltips = [
#      63     ('3P Mades per Game', "@y"),
#      64      ('3P Attempted Per Game', "@x"),
#      65     ('3P Percentage','@Percentages'),
#      66  ('Position', '@Position'),('Player','@Player')])
#      68 p = figure(height=600,
#      69            width = 700,
#      70            x_range = (0,1000),
#    (...)
#      74           x_axis_label = "Three Attempted",
#      75           y_axis_label = "Three Made")
#
# File ~\anaconda3\lib\site-packages\bokeh\models\mappers.py:98, in ColorMapper.__init__(self, palette, **kwargs)
#      96 if palette is not None:
#      97     kwargs['palette'] = palette
# ---> 98 super().__init__(**kwargs)
#
# File ~\anaconda3\lib\site-packages\bokeh\model\model.py:128, in Model.__init__(self, **kwargs)
#     121 def __init__(self, **kwargs: Any) -> None:
#     122
#     123     # "id" is popped from **kw in __new__, so in an ideal world I don't
#     124     # think it should be here too. But Python has subtle behavior here, so
#     125     # it is necessary
#     126     kwargs.pop("id", None)
# --> 128     super().__init__(**kwargs)
#     129     default_theme.apply_to_model(self)
#
# File ~\anaconda3\lib\site-packages\bokeh\core\has_props.py:206, in HasProps.__init__(self, **properties)
#     203 self._unstable_themed_values = {}
#     205 for name, value in properties.items():
# --> 206     setattr(self, name, value)
#     208 self._initialized = True
#
# File ~\anaconda3\lib\site-packages\bokeh\core\has_props.py:230, in HasProps.__setattr__(self, name, value)
#     228 properties = self.properties(_with_props=True)
#     229 if name in properties:
# --> 230     return super().__setattr__(name, value)
#     232 descriptor = getattr(self.__class__, name, None)
#     233 if isinstance(descriptor, property): # Python property
#
# File ~\anaconda3\lib\site-packages\bokeh\core\property\descriptors.py:283, in PropertyDescriptor.__set__(self, obj, value, setter)
#     280     class_name = obj.__class__.__name__
#     281     raise RuntimeError(f"{class_name}.{self.name} is a readonly property")
# --> 283 value = self.property.prepare_value(obj, self.name, value)
#     284 old = self._get(obj)
#     285 self._set(obj, old, value, setter=setter)
#
# File ~\anaconda3\lib\site-packages\bokeh\core\property\bases.py:365, in Property.prepare_value(self, owner, name, value, hint)
#     363 else:
#     364     obj_repr = owner if isinstance(owner, HasProps) else owner.__name__
# --> 365     raise ValueError(f"failed to validate {obj_repr}.{name}: {error}")
#     367 if isinstance(owner, HasProps):
#     368     obj = owner
#
# ValueError: failed to validate CategoricalColorMapper(id='10083', ...).factors: expected an element of either Seq(String), Seq(Tuple(String, String)) or Seq(Tuple(String, String, String)), got ['G', 'SG', 'SF', 'F', 'PG', 'C', 'PF', nan]
